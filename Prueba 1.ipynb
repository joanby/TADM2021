# %% [markdown]
# # Prueba número 1 de `python`

# %%
print("Hola, que tal?")
# Out:
# Hola, que tal?

# %%
x = input("Dime cómo te llamas: ")
# Out:
# Dime cómo te llamas: Juan Gabriel Gomila

# %%
x
# Out:
# 'Juan Gabriel Gomila'

# %%
import matplotlib.pyplot as plt

plt.plot([1,2,3], [1,5,15])
